# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # Module 1: Importing Data Sets

# %% [markdown]
# ## Introduction
#
# In this notebook, we will evaluate the performance of various machine learning models using different metrics. The models we will evaluate include linear regression, k-NN, decision tree, logistic regression, and SVM. We will use a dataset to train and test these models, calculate metrics such as accuracy, Jaccard index, F1 score, and log loss, and compare the results to determine which model performs best in this context.

# %% [markdown]
# ## Data Science Languages
#
# 1. Python
# 2. R
# 3. SQL
# 4. Julia
# 5. MATLAB
# 6. Scala
# 7. Java
# 8. C/C++
# 9. JavaScript
# 10. SAS

# %% [markdown]
# ## Data Science Libraries in Python
#
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - TensorFlow
# - Keras
# - PyTorch
# - SciPy
# - Statsmodels

# %% [markdown]
# | Tool             | Description                                             |
# |------------------|---------------------------------------------------------|
# | Jupyter Notebook | Interactive environment for developing and sharing code |
# | RStudio          | IDE for programming in R                                 |
# | Apache Hadoop    | Framework for distributed processing of large datasets |
# | Apache Spark     | Cluster computing engine for data analysis              |
# | Tableau          | Data visualization tool                                  |
# | SAS              | Statistical analysis system                               |
# | Excel            | Spreadsheet software                                     |
# | KNIME            | Data analytics platform                                  |
# | RapidMiner       | Data science and machine learning platform               |
# | Databricks       | Apache Spark-based data analytics platform               |

# %% [markdown]
# Examples of arithmetic expressions:
#
# 1. Addition: 2 + 3 = 5
# 2. Subtraction: 5 - 3 = 2
# 3. Multiplication: 4 * 6 = 24
# 4. Division: 10 / 2 = 5
# 5. Exponentiation: 2^3 = 8
# 6. Square root: √9 = 3
# 7. Parentheses: (4 + 5) * 3 = 27
# 8. Modulus (remainder of division): 10 % 3 = 1

# %%
# Multiplication
multiplication_result = 5 * 3
print("The result of the multiplication is:", multiplication_result)

# Addition
addition_result = 5 + 3
print("The result of the addition is:", addition_result)
# Out:
# The result of the multiplication is: 15
# The result of the addition is: 8

# %%
# Definition of the function to convert minutes to hours
def minutes_to_hours(minutes):
    hours = minutes / 60
    return hours

# Example of using the function
minutes = 150
hours = minutes_to_hours(minutes)
print(f"{minutes} minutes are equivalent to {hours} hours")
# Out:
# 150 minutes are equivalent to 2.5 hours

# %%
# List of objectives
objectives = [
    "Learn new concepts in data science",
    "Practice programming skills in Python",
    "Develop machine learning models",
    "Analyze datasets to gain insights",
    "Improve data visualization skills",
    "Apply statistical techniques for decision making",
    "Communicate data analysis results effectively"
]

# Print the objectives
print("Objectives:")
for objective in objectives:
    print("-", objective)
# Out:
# Objectives:
# - Learn new concepts in data science
# - Practice programming skills in Python
# - Develop machine learning models
# - Analyze datasets to gain insights
# - Improve data visualization skills
# - Apply statistical techniques for decision making
# - Communicate data analysis results effectively

# %% [markdown]
# Author: [Ashanty González Concha]
